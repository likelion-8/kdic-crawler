# %% [markdown]
# # 임베딩 모델 4종 비교 (embedding_test_dy)
#
# 프로젝트2 임베딩 모델 선정 — **bge-m3 / bge-m3-ko / Qwen3-Embedding-8B / Nemotron-3-Embed-8B**.
# 동일 코퍼스(494청크)·동일 테스트셋(557문항)으로 Recall@k·MRR·인코딩 속도 측정. 팀(embedding_test_yj)과 동일 ID·API로 맞춰 비교 가능.
#
# **런타임 → GPU (A100 권장)** — 8B 2종은 bf16 가중치만 ~16GB라 T4(16GB)면 빠듯. OOM 시 `MODELS`의 batch_size를 1로.
# 모델 ID·API 스타일은 `src/eval_embeddings.py` 의 `MODELS` 에서 관리.

# %%
# 1) 의존성 — 최신으로. 8B(bf16) 로딩에 accelerate, Nemotron 원격코드에 einops 필요
# !pip -q install -U sentence-transformers transformers accelerate einops

# %%
# 2) 저장소 clone (private면 GitHub 토큰 필요). 토큰 입력창이 뜨면 붙여넣기.
import getpass, os
tok = getpass.getpass('GitHub token (public이면 그냥 Enter): ').strip()
url = f'https://{tok}@github.com/likelion-8/kdic-crawler.git' if tok else 'https://github.com/likelion-8/kdic-crawler.git'
# !rm -rf kdic-crawler
# !git clone -b embedding_test_dy {url}
# %cd kdic-crawler

# %%
# 3) GPU 확인
import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else '')

# %%
# 4) 비교 실행 — 모델별 로딩·인코딩·평가. 결과표 출력 + data/embedding_eval/dy.json 저장
# !python src/eval_embeddings.py

# %%
# 5) 결과 JSON 확인 (팀원 파일과 합쳐 비교)
import json; print(json.dumps(json.load(open('data/embedding_eval/dy.json', encoding='utf-8')), ensure_ascii=False, indent=2))
